# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from numpy import genfromtxt
my_data = genfromtxt('image.csv', delimiter=',')

# %%
plt.imshow(my_data, cmap='gray')

# %%
my_data.shape
# Out:
# (120, 160)
